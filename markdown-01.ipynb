# %% [markdown]
# # Presentacion personal

# %% [markdown]
# ## Manuel Escalante

# %% [markdown]
# Tengo **19** años, y estudio la carrera de *ingenieria civil*

# %% [markdown]
# ### Que es una trabe?

# %% [markdown]
# los trabes son el sostén de los techos, muros y/o refuerzo en las ventanas. Lo usual en uso domestico, es realizar la estructura con varillas de distintos calibres y estribos, segun recomiende el calculista, para despues colarla con el concreto elaborado a una resistencia previamente calculada
# Hay de:
#  - Madera
#  -Acero

# %% [markdown]
# ![image.png](attachment:image.png)
